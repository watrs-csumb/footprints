# %% [markdown]
# ### Mount Drive

# %%
try:
    from google.colab import drive # type: ignore
    drive.mount('/content/home')
except ImportError:
    pass
# Out:
# Mounted at /content/home

# %% [markdown]
# ### DIR and DEPENDENCIES

# %%
import sys
import pathlib

colab_data = pathlib.Path('/content/home/MyDrive/B_SanLuis')
local_data = pathlib.Path("../data/")

DIR = colab_data if colab_data.exists() else local_data
sys.path.append(str(DIR / 'Scripts'))



CropConcern = 'Lettuce2024' #Change between Broccoli and Lettuce
latitude, longitude = 36.456667, 121.382222 #tower location
hemisphere = 'north'

if CropConcern == 'Broccoli2023' :
  in_df = DIR / '/Data/1_Intermediate_Datasets/Broccoli/Broccoli2023FP.csv'
  Json_out_df = DIR / '/Data/1_Intermediate_Datasets/Broccoli/Json/'
  out_df = DIR / '/Data/'

if CropConcern == 'Lettuce2023' :
  in_df = DIR / '/Data/1_Intermediate_Datasets/Lettuce/Lettuce2023FP.csv'
  Json_out_df = DIR / '/Data/1_Intermediate_Datasets/Lettuce/Json/'
  out_df = DIR / '/Data/'

if CropConcern == 'Lettuce2024' :
  in_df = DIR / '/Data/1_Intermediate_Datasets/Lettuce/Lettuce2024FP.csv'
  Json_out_df = DIR / '/Data/1_Intermediate_Datasets/Lettuce/Json/'
  out_df = DIR / '/Data/'

# %%
#import dependencies
import src.calc_footprint_FFP as ffp  # noqa: E402
#import calc_footprint_FFP_climatology as ffp_clim
import pandas as pd  # noqa: E402
import pyproj as proj  # noqa: E402
import numpy as np  # noqa: E402
import geopandas as gpd  # noqa: E402
from shapely.geometry import Polygon # noqa: E402  
from shapely.ops import unary_union # noqa: E402
from shapely.geometry import Point # noqa: E402
from shapely.geometry import shape # noqa: E402
from shapelysmooth import taubin_smooth # noqa: E402
from pyproj import Transformer # noqa: E402
import rasterio # noqa: E402
from rasterio.transform import from_origin # noqa: E402
from rasterio.features import rasterize # noqa: E402
from rasterio.features import shapes # noqa: E402
from rasterio import features # noqa: E402
import matplotlib.pyplot as plt # noqa: E402

# %% [markdown]
# ###Extract from FFP

# %%
# Calculate UTM zone and CRS based on tower location (set latlon in dependencies)
towercoordinates = np.array([[latitude, longitude]])  # tower's lat/lon
utmzone = int((longitude + 180) / 6) + 1  # calculate UTM zone based on longitude
utm_crs = f"+proj=utm +zone={utmzone} +datum=WGS84 +units=m +no_defs"  # create UTM CRS

# Transformer for lat/lon to UTM coordinates
transformer = Transformer.from_crs("epsg:4326", utm_crs)

# Function to convert lat/lon to UTM coordinates
def convert_to_utm(lat_lon):
    lat, lon = lat_lon
    easting, northing = transformer.transform(lat, lon)
    return easting, northing  # meters from bottom left of UTM zone

# Convert tower coordinates to UTM
tower_utm_coordinates = np.apply_along_axis(convert_to_utm, axis = 1, arr = towercoordinates)
easting, northing = tower_utm_coordinates[0]

# %%
# Initialize an empty list to hold all the polygons
polygons = []

# Load crop data
crop_df = pd.read_csv(in_df)  # CSV contains 1048 rows

# Limit rows processed (for memory reasons) ~ 300 max
for index, row in crop_df.iterrows():
    if index >= 300:  # set to and # of rows
        break

    try:
        # Initialize the Footprint Model (FFP)
        TestFPmodel = ffp.FFP(
            zm = row['zm'],
            z0 = row['z0'],
            umean = row['u_mean'],
            h = 2000,
            ol = row['L'],
            sigmav = row['sigma_v'],
            ustar = row['u_star'],
            wind_dir = row['wind_dir'],
            rs = [90],
            fig = 0  # set to 1 if you want to plot the figure
        )

        # Extract xr, yr coordinates and shift them by tower's UTM coordinates
        xr = np.array(TestFPmodel['xr'][0]) + easting
        yr = np.array(TestFPmodel['yr'][0]) + northing

        # Create Polygon from xr, yr coordinate pairs
        polygon_coords = Polygon(zip(xr, yr))

        # Append the polygon to the list
        polygons.append(polygon_coords)

    except KeyError as e:
        print(f"KeyError in row {index}: {e}")
    except ValueError as e:
        print(f"ValueError in row {index}: {e}")
    except Exception as e:
        print(f"Error in row {index}: {e}")
        continue

# Create GeoDataFrame from all collected polygons at once
gdf = gpd.GeoDataFrame(geometry = polygons, crs = utm_crs)

# Optionally save the intermediates as GeoJSON
Json_output_path = Json_out_df + CropConcern + '_all.geojson'
gdf.to_file(Json_output_path, driver='GeoJSON')
print(f"All polygons saved as {Json_output_path}")
# Out:
# Error(0009):
#  ustar (friction velocity) must be >=0.1.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 0: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 1: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 2: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 3: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 4: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 5: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 6: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 7: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 8: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 9: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 10: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 11: local variable 'psi_f' referenced before assignment
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 12: local variable 'psi_f' referenced before assignment
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 13: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 14: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 15: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 16: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 17: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 18: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 19: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 20: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 21: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 22: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 23: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 24: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 25: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 26: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 27: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 28: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 29: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 30: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 31: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 32: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 33: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 34: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 35: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 36: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 37: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 38: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 39: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 40: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 41: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 42: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 43: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 44: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 45: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 46: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 47: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 48: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 49: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 50: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 51: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 52: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 53: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 54: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 55: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 56: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 57: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 58: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 59: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 60: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 61: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 62: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 63: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 64: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 65: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 66: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 67: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 68: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 69: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 70: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 71: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 72: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 73: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 74: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 75: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 76: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 77: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 78: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 79: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 80: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 81: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 82: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 83: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 84: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 85: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 86: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 87: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 88: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 89: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 90: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 91: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 92: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 93: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 94: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 95: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 96: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 97: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 98: invalid index to scalar variable.
#
# Error(0009):
#  ustar (friction velocity) must be >=0.1.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 99: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 100: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 101: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 102: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 103: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 104: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 105: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 106: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 107: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 108: invalid index to scalar variable.
#
# Error(0009):
#  ustar (friction velocity) must be >=0.1.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 109: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 110: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 111: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 112: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 113: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 114: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 115: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 116: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 117: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 118: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 119: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 120: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 121: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 122: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 123: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 124: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 125: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 126: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 127: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 128: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 129: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 130: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 131: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 132: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 133: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 134: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 135: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 136: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 137: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 138: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 139: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 140: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 141: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 142: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 143: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 144: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 145: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 146: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 147: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 148: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 149: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 150: invalid index to scalar variable.
#
# Error(0009):
#  ustar (friction velocity) must be >=0.1.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 151: invalid index to scalar variable.
#
# Error(0009):
#  ustar (friction velocity) must be >=0.1.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 152: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 153: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 154: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 155: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 156: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 157: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 158: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 159: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 160: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 161: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 162: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 163: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 164: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 165: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 166: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 167: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 168: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 169: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 170: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 171: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 172: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 173: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 174: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 175: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 176: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 177: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 178: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 179: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 180: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 181: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 182: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 183: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 184: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 185: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 186: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 187: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 188: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 189: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 190: invalid index to scalar variable.
#
# Error(0009):
#  ustar (friction velocity) must be >=0.1.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 191: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 192: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 193: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 194: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 195: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 196: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 197: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 198: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 199: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 200: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 201: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 202: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 203: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 204: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 205: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 206: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 207: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 208: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 209: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 210: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 211: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 212: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 213: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 214: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 215: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 216: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 217: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 218: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 219: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 220: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 221: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 222: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 223: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 224: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 225: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 226: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 227: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 228: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 229: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 230: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 231: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 232: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 233: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 234: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 235: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 236: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 237: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 238: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 239: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 240: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 241: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 242: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 243: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 244: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 245: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 246: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 247: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 248: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 249: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 250: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 251: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 252: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 253: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 254: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 255: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 256: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 257: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 258: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 259: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 260: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 261: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 262: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 263: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 264: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 265: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 266: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 267: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 268: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 269: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 270: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 271: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 272: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
# Error in row 273: invalid index to scalar variable.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.

# %% [markdown]
# ###Polygon to Raster

# %%
# Check if there is anything in gdf
if not gdf.empty:
    # Find furthest extent of polygons
    minx, miny, maxx, maxy = gdf.unary_union.bounds
    print(f"Overall extent: minx = {minx}, miny = {miny}, maxx = {maxx}, maxy = {maxy}")
else:
    print("No polygons were processed.")

# %%
# Input desired resolution
resolution = 1  # meters per pixel
width = int((maxx - minx) / resolution)
height = int((maxy - miny) / resolution)

# Create array to hold all individual rasters
accumulated_raster = np.zeros((height, width), dtype=np.uint8)

# Set transformation matrix based on the bounding box
transform = from_origin(minx, maxy, resolution, resolution)

# %%
# Iterate over all polygons in the GeoDataFrame and rasterize them
for index, row in gdf.iterrows():
    try:
        polygon = [row['geometry']]  # Convert polygon to list
        rasterized = features.rasterize(
            polygon,
            out_shape = (height, width),
            fill = 0,
            transform = transform
        )

        # Ensure rasterized data matches the dtype of the accumulated_raster
        rasterized = rasterized.astype(accumulated_raster.dtype)

        # Accumulate the rasterized polygon to the overall raster
        accumulated_raster += rasterized

    except KeyError as e:
        print(f"KeyError in row {index}: {e}")
    except Exception as e:
        print(f"Error in row {index}: {e}")
        continue

# Plot the accumulated raster with chosen colormap
fig, ax = plt.subplots()
# Set colormap (adjust as needed; 'hot' is currently used, but you can change this)
cax = ax.imshow(accumulated_raster, cmap = 'hot', extent = (minx, maxx, miny, maxy))

# Set labels and title
ax.set_xlabel('Easting (m)')
ax.set_ylabel('Northing (m)')
plt.colorbar(cax, ax = ax, label = 'Overlap Count')
plt.title('Accumulated Raster with Overlap')

# Display the plot
plt.show()

# %% [markdown]
# ###Rid of zeroes

# %%
# Identify all non-zero pixels and their values
non_zero_pixels = np.nonzero(accumulated_raster)  # Returns indices of non-zero pixels
non_zero_values = accumulated_raster[non_zero_pixels]  # Extract the actual values of non-zero pixels

# Get the corresponding coordinates (x, y) for each non-zero pixel
xs, ys = rasterio.transform.xy(transform, non_zero_pixels[0], non_zero_pixels[1])

# Create Point geometries from x, y coordinates
geometries = [Point(x, y) for x, y in zip(xs, ys)]

# Create a GeoDataFrame to hold the geometries and the overlap counts
accumulated_raster_non_zero = gpd.GeoDataFrame({
    'geometry': geometries,
    'overlap_count': non_zero_values
}, crs = utm_crs)

# %%
# Plot the non-zero overlap pixels using GeoPandas
fig, ax = plt.subplots(figsize=(6, 6))
accumulated_raster_non_zero.plot(
    ax = ax,
    column = 'overlap_count',
    cmap = 'hot',
    legend = True,
    legend_kwds = {'label': "Overlap Count"}
)

# Label the axes and set the title
ax.set_xlabel('Easting (m)')
ax.set_ylabel('Northing (m)')
ax.set_title('Non-Zero Overlap Pixels')

# Display the plot
plt.show()

# %% [markdown]
# ###Raster to Vector

# %%
# Find the maximum overlap value directly inside the function
def raster_to_polygon(raster, transform, threshold_ratio = 0.8):
    max_overlaps = np.max(raster)  # Find max directly in the function
    mask = raster > (max_overlaps * threshold_ratio)  # Mask based on threshold (80% of max)
    shapes_gen = shapes(raster, mask = mask, transform = transform)  # Generate shapes

    # Convert shapes to polygons
    return [shape(geom) for geom, _ in shapes_gen]

# %%
# Generate polygons from raster
raster_to_polygons = raster_to_polygon(accumulated_raster, transform)

# Merge the polygons into a single unified polygon
combined_vector_polygons = unary_union(raster_to_polygons)

# Create GeoDataFrame from the combined polygon
vector_gdf = gpd.GeoDataFrame(geometry = [combined_vector_polygons], crs = utm_crs)


# Smooth the polygon geometry, catching potential smoothing errors
try:
    vector_gdf.loc[0, 'geometry'] = taubin_smooth(vector_gdf.loc[0, 'geometry'], steps = 50)
except Exception as e:
    print(f"Error in smoothing polygon: {e}")
#the taubin_smooth function smoothes the geometry without changing the number of vertices

# %%
# Plot the final smoothed polygon
fig, ax = plt.subplots(figsize = (6, 6))
vector_gdf.plot(ax = ax, edgecolor = 'black', facecolor = 'none')
ax.set_xlabel('Easting (m)')
ax.set_ylabel('Northing (m)')
plt.title('Polygon')

plt.show()

# %%
# Save final
GeoJson_output_path = out_df + CropConcern + 'Final.geojson'
vector_gdf.to_file(GeoJson_output_path, driver = 'GeoJSON')

# %%
vector_gdf

# %%
vector_gdf['geometry'][0].area
